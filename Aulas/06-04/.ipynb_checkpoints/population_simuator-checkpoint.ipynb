# %% [markdown]
# 1. Terminar o mapa logístico, incluindo a visualização do sistema dinâmico
#
#     _(Parábola com a reta e o caracol)_
#
# 1. Vizualizar soluções das equações de lorenz usando o algoritmo de euler

# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot([0]*1001)
ax.set_ylim([0, 1])
#line, = ax.plot(x, np.sin(x))


#@interact(p0=(0.0,1.0,0.01), a=(0.0,1.0,0.01))
def update(p0 = 0.5, a = 0.1):
    W = [p0]
    for i in range(1000):
        W.append(W[-1]*a)
    line.set_ydata(W)
    fig.canvas.draw()
    
interact(update, p0=(0.0,1.0,0.01), a=(0.0,1.0,0.01))
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(FloatSlider(value=0.5, description='p0', max=1.0, step=0.01), FloatSlider(value=0.1, description='a', max=1.0, step=0.01), Output()), _dom_classes=('widget-interact',))
# <function __main__.update>

# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot([0]*1001, linestyle=" ", marker='o', markersize=1)
ax.set_ylim([0, 1])


def update(x0=0.5, r=0.1):
    X = [x0]
    for i in range(1000):
        X.append(r*X[-1]*(1-X[-1]))
    line.set_ydata(X)
    fig.canvas.draw()
    
interact(update, x0=(0.0,1.0,0.01), r=(0.0,4.0,0.01))
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(FloatSlider(value=0.5, description='x0', max=1.0, step=0.01), FloatSlider(value=0.1, description='r', max=4.0, step=0.01), Output()), _dom_classes=('widget-interact',))
# <function __main__.update>

# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

it = 1000

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot([0, 1], [0, 1], linestyle="-", markersize=1, color="red")
line_f, = ax.plot([ i/it for i in range(it)], [0]*it, linestyle="-", marker="", markersize=1, color="blue")
line_x, = ax.plot([0]*it, [0]*it, linestyle="-", marker="o", markersize=1, color=(0,1,0,0.5))
ax.set_xlim([0, 1])
ax.set_ylim([0, 1])


def update(x0=0.5, r=0.1):
    f = []
    for i in range(it):
        i = i/it
        f.append(r*i*(1-i))

    x, y = [x0], [0]
    for i in range(it-1):
        if i % 2 == 0:
            x.append(x[-1])
            y.append(r*x[-1]*(1-x[-1]))
        else:
            x.append(y[-1])
            y.append(y[-1])

    line_f.set_ydata(f)
    line_x.set_xdata(x)
    line_x.set_ydata(y)
    fig.canvas.draw()
    
interact(update, x0=(0.0,1.0,0.01), r=(0.0,4.0,0.01))
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(FloatSlider(value=0.5, description='x0', max=1.0, step=0.01), FloatSlider(value=0.1, description='r', max=4.0, step=0.01), Output()), _dom_classes=('widget-interact',))
# <function __main__.update>

# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

it = 100

fig, ax = plt.subplots()
fig.set_tight_layout(True)

lines = [
    ax.plot([i/it]*it, [0]*it, linestyle="", marker="o", markersize=1, color=(0, 0, 1))[0]
    for i in range(it)
]

ax.set_xlim([0, 1])
ax.set_ylim([0, 1])


def update(r=0.1):
    for line in range(it):
        x = line/it
        
        y = [x]
        for i in range(it-1):
            y.append(r*y[-1]*(1-y[-1]))
            
        lines[line].set_ydata(y)
            
    fig.canvas.draw()
    
interact(update, r=(0.0,4.0,0.01))
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(FloatSlider(value=0.1, description='r', max=4.0, step=0.01), Output()), _dom_classes=('widget-interact',))
# <function __main__.update>

# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

it = 200

fig, ax = plt.subplots()
fig.set_tight_layout(True)

lines = [
    ax.plot([j/it for j in range(it)], [i/it]*it, linestyle="", marker="o", markersize=1, color=(0, 0, 1, i/it))[0]
    for i in range(it)
]

ax.set_xlim([0, 1])
ax.set_ylim([0, 1])


def update(r=0.1):
    
    y = [
        j/it for j in range(it)
    ]

    for i in range(it):
        for j in range(it):
            y[j] = r*y[j]*(1-y[j])
        
        lines[i].set_ydata(list(y))
            
    fig.canvas.draw()
    
interact(update, r=(0.0,4.0,0.01))
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(FloatSlider(value=0.1, description='r', max=4.0, step=0.01), Output()), _dom_classes=('widget-interact',))
# <function __main__.update>

# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

it = 1000
rs = 100

fig, ax = plt.subplots()
fig.set_tight_layout(True)

lines = [
    ax.plot([4*i/rs]*it, [0]*it, linestyle="", marker="o", markersize=1, color=(0, 0, 1, 0.1))[0]
    for i in range(rs)
]

ax.set_xlim([0, 4])
ax.set_ylim([0, 1])


def update(x0=0.1):
    

    for i in range(rs):
        y = [x0]
        for j in range(10):
            y[0] = (4*i/rs)*y[0]*(1-y[0])
        for j in range(it-1):
            y.append((4*i/rs)*y[-1]*(1-y[-1]))
        
        lines[i].set_ydata(y)
            
    fig.canvas.draw()
    
interact(update, x0=(0.0,1.0,0.01))
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(FloatSlider(value=0.1, description='x0', max=1.0, step=0.01), Output()), _dom_classes=('widget-interact',))
# <function __main__.update>

# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

# mapas de lorenz

it = 10000
dt = 0.001

fig, ax = plt.subplots()
fig.set_tight_layout(True)

a = 0.5
b = 0.5

x = [0.5]
y = [0.5]

for i in range(it-1):
    x.append(y[i-1] - a*x[i-1]**2)
    y.append(b*x[i-1])

line, = ax.plot(x, y, linestyle="-", marker="o", markersize=1, color=(0, 0, 1))

ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])


def update(x0=0.5, y0=-0.5, a=0.5, b=-0.5):

    x = [x0]
    y = [y0]

    for i in range(it-1):
        x.append(y[i-1] - a*x[i-1]**2)
        y.append(b*x[i-1])
        
    line.set_xdata(x)
    line.set_ydata(y)
            
    fig.canvas.draw()
    
interact(update, x0=(-1.0,1.0,0.01), y0=(-1.0,1.0,0.01), a=(-1.0,1.0,0.01), b=(-1.0,1.0,0.01))
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(FloatSlider(value=0.5, description='x0', max=1.0, min=-1.0, step=0.01), FloatSlider(value=-0.5, description='y0', max=1.0, min=-1.0, step=0.01), FloatSlider(value=0.5, description='a', max=1.0, min=-1.0, step=0.01), FloatSlider(value=-0.5, description='b', max=1.0, min=-1.0, step=0.01), Output()), _dom_classes=('widget-interact',))
# <function __main__.update>
